# %%
import LoadDatas as ld
import Statistics as st
import Visualisations as vs
import Config as cf
import Metrics as me
import Models as mo
import gc 


conf = cf.Config()
# Out:
# Current version 1.2
# 2023-03-24 16:29:36.928716: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
"""
Get resources and updates config when its done
"""

#Load AOIs and images
aoisByImage = ld.getAOIListByImage(conf)
conf.aoisByImage = aoisByImage
conf.ARE_AOIS_LOAD = aoisByImage != None

imageList = ld.getImageList(conf)

conf.imageList = imageList
conf.ARE_IMAGES_LOAD = imageList != None

#Get the fixations from the folder FIXATIONS
fixations = ld.getFixations(conf)
conf.fixations = fixations
conf.ARE_FIXATIONS_LOAD = conf.fixations != None

print(len(fixations))
gc.collect()
# Out:
# 11
# 0

# %%
"""
Statistics
"""
if conf.ARE_IMAGES_LOAD and conf.ARE_AOIS_LOAD and conf.ARE_FIXATIONS_LOAD:

    #Compute statistic by user
    statistics = st.getUserStatistics(conf)
    #print('keys1',sorted(statistics.keys()))
    #print(statistics['181020221524'][0].aoiStats)

    #Print statistics by user
    '''
    for user in statistics:
        imStatList =statistics[user]
        for imStat in imStatList:
            imStatList[imStat].printStatistics()
    '''

    #Compute global statistics by image
    statGlob = st.computeGlobalStatistic(statistics, conf)
    

    #Print statistics
    st.printStatistics(statGlob,conf)
    
    #Create histograms
    vs.createAllHistograms(statGlob,conf)
    
    #Force garbage collection
    gc.collect()
    print("2")
# Out:
# /Users/admin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/admin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/admin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:262: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/admin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:222: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /Users/admin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ================================
# Average statistics over all users
# ================================
# Image n°1 (Vaillant_0633_1957_06_30-22)
# Image n°11 (Vaillant_0623_1957_04_21-09)
# Image n°16 (Vaillant_0618_1957_03_17-06)
# 	----------------
# 	AOI n°0 (participation of 12 observers)
# 		Mean fixation number : 0.417 (SD = 0.759) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.579 (SD = 1.208) | Range : 0.0 - 3.413
# 		Mean fixation duration (ms) : 306.917 (SD = 604.369) | Range : 0 - 1706.5
# 		Mean gaze number : 0.417 (SD = 0.759) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 62406.0 (SD = 8108.699) | Range : -1 - 72438
# 	----------------
# 	----------------
# 	AOI n°1 (participation of 12 observers)
# 		Mean fixation number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.12 (SD = 0.275) | Range : 0.0 - 0.864
# 		Mean fixation duration (ms) : 120.083 (SD = 274.831) | Range : 0 - 864.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 96000.5 (SD = 20416.5) | Range : -1 - 116417
# 	----------------
# 	----------------
# 	AOI n°2 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°3 (participation of 12 observers)
# 		Mean fixation number : 0.333 (SD = 0.624) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.069 (SD = 0.126) | Range : 0.0 - 0.343
# 		Mean fixation duration (ms) : 56.167 (SD = 105.942) | Range : 0 - 343.0
# 		Mean gaze number : 0.333 (SD = 0.624) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 111244.667 (SD = 8807.028) | Range : -1 - 119762
# 	----------------
# 	----------------
# 	AOI n°4 (participation of 12 observers)
# 		Mean fixation number : 0.417 (SD = 0.759) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.17 (SD = 0.335) | Range : 0.0 - 1.033
# 		Mean fixation duration (ms) : 95.458 (SD = 173.821) | Range : 0 - 516.5
# 		Mean gaze number : 0.417 (SD = 0.759) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 102915.333 (SD = 11931.863) | Range : -1 - 116276
# 	----------------
# 	----------------
# 	AOI n°5 (participation of 12 observers)
# 		Mean fixation number : 3.083 (SD = 2.253) | Range : 1 - 9
# 		Mean viewing time (sec) : 2.322 (SD = 1.807) | Range : 0.23 - 6.032
# 		Mean fixation duration (ms) : 748.955 (SD = 341.027) | Range : 230.0 - 1209.333
# 		Mean gaze number : 2.417 (SD = 1.754) | Range : 1 - 7
# 		Mean time to first fixation (ms) : 11783.667 (SD = 12365.601) | Range : 0 - 40159
# 	----------------
# 	----------------
# 	AOI n°6 (participation of 12 observers)
# 		Mean fixation number : 2.417 (SD = 1.605) | Range : 0 - 5
# 		Mean viewing time (sec) : 1.871 (SD = 1.406) | Range : 0.0 - 4.191
# 		Mean fixation duration (ms) : 613.367 (SD = 441.159) | Range : 0 - 1397.0
# 		Mean gaze number : 1.75 (SD = 1.164) | Range : 0 - 4
# 		Mean time to first fixation (ms) : 48047.6 (SD = 10385.503) | Range : 30267 - 68152
# 	----------------
# 	----------------
# 	AOI n°7 (participation of 12 observers)
# 		Mean fixation number : 3.333 (SD = 2.625) | Range : 0 - 7
# 		Mean viewing time (sec) : 2.641 (SD = 2.645) | Range : 0.0 - 8.686
# 		Mean fixation duration (ms) : 538.896 (SD = 434.293) | Range : 0 - 1447.667
# 		Mean gaze number : 2.75 (SD = 2.087) | Range : 0 - 6
# 		Mean time to first fixation (ms) : 57750.222 (SD = 22985.356) | Range : -1 - 104560
# 	----------------
# 	----------------
# 	AOI n°8 (participation of 12 observers)
# 		Mean fixation number : 1.667 (SD = 2.427) | Range : 0 - 8
# 		Mean viewing time (sec) : 1.249 (SD = 2.431) | Range : 0.0 - 8.753
# 		Mean fixation duration (ms) : 305.552 (SD = 387.443) | Range : 0 - 1094.125
# 		Mean gaze number : 1.583 (SD = 2.396) | Range : 0 - 8
# 		Mean time to first fixation (ms) : 56043.167 (SD = 18002.66) | Range : -1 - 86868
# 	----------------
# 	----------------
# 	AOI n°9 (participation of 12 observers)
# 		Mean fixation number : 1.167 (SD = 1.143) | Range : 0 - 4
# 		Mean viewing time (sec) : 0.585 (SD = 0.748) | Range : 0.0 - 2.76
# 		Mean fixation duration (ms) : 311.5 (SD = 278.45) | Range : 0 - 819.0
# 		Mean gaze number : 1.167 (SD = 1.067) | Range : 0 - 3
# 		Mean time to first fixation (ms) : 90277.25 (SD = 18714.123) | Range : 64633 - 121125
# 	----------------
# 	----------------
# 	AOI n°10 (participation of 12 observers)
# 		Mean fixation number : 4.75 (SD = 1.738) | Range : 2 - 9
# 		Mean viewing time (sec) : 3.865 (SD = 1.779) | Range : 1.157 - 7.3
# 		Mean fixation duration (ms) : 816.202 (SD = 259.563) | Range : 385.667 - 1318.5
# 		Mean gaze number : 3.167 (SD = 1.28) | Range : 2 - 6
# 		Mean time to first fixation (ms) : 44440.75 (SD = 16031.636) | Range : 13201 - 69568
# 	----------------
# 	----------------
# 	AOI n°11 (participation of 12 observers)
# 		Mean fixation number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.088 (SD = 0.215) | Range : 0.0 - 0.742
# 		Mean fixation duration (ms) : 87.75 (SD = 215.036) | Range : 0 - 742.0
# 		Mean gaze number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 13673.5 (SD = 13673.5) | Range : -1 - 27347
# 	----------------
# 	----------------
# 	AOI n°12 (participation of 12 observers)
# 		Mean fixation number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.027 (SD = 0.09) | Range : 0.0 - 0.326
# 		Mean fixation duration (ms) : 27.167 (SD = 90.102) | Range : 0 - 326.0
# 		Mean gaze number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 87369.0 (SD = 0.0) | Range : -1 - 87369
# 	----------------
# 	----------------
# 	AOI n°13 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°14 (participation of 12 observers)
# 		Mean fixation number : 0.5 (SD = 0.645) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.258 (SD = 0.367) | Range : 0.0 - 0.996
# 		Mean fixation duration (ms) : 220.375 (SD = 318.118) | Range : 0 - 996.0
# 		Mean gaze number : 0.5 (SD = 0.645) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 74819.2 (SD = 31207.841) | Range : -1 - 130907
# 	----------------
# 	----------------
# 	AOI n°15 (participation of 12 observers)
# 		Mean fixation number : 2.917 (SD = 1.605) | Range : 1 - 6
# 		Mean viewing time (sec) : 2.411 (SD = 1.932) | Range : 0.145 - 6.772
# 		Mean fixation duration (ms) : 797.124 (SD = 493.506) | Range : 145.0 - 1693.0
# 		Mean gaze number : 2.333 (SD = 1.434) | Range : 0 - 5
# 		Mean time to first fixation (ms) : 10995.333 (SD = 8251.257) | Range : 0 - 28483
# 	----------------
# 	----------------
# 	AOI n°16 (participation of 12 observers)
# 		Mean fixation number : 0.333 (SD = 0.624) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.104 (SD = 0.208) | Range : 0.0 - 0.666
# 		Mean fixation duration (ms) : 85.708 (SD = 187.792) | Range : 0 - 666.0
# 		Mean gaze number : 0.333 (SD = 0.624) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 68961.0 (SD = 5892.936) | Range : -1 - 75945
# 	----------------
# 	----------------
# 	AOI n°17 (participation of 12 observers)
# 		Mean fixation number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.043 (SD = 0.142) | Range : 0.0 - 0.512
# 		Mean fixation duration (ms) : 42.667 (SD = 141.509) | Range : 0 - 512.0
# 		Mean gaze number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 38264.0 (SD = 0.0) | Range : -1 - 38264
# 	----------------
# 	----------------
# 	AOI n°18 (participation of 12 observers)
# 		Mean fixation number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.064 (SD = 0.161) | Range : 0.0 - 0.568
# 		Mean fixation duration (ms) : 63.5 (SD = 161.212) | Range : 0 - 568.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 64666.0 (SD = 19669.0) | Range : 44997 - 84335
# 	----------------
# 	----------------
# 	AOI n°19 (participation of 12 observers)
# 		Mean fixation number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.035 (SD = 0.082) | Range : 0.0 - 0.266
# 		Mean fixation duration (ms) : 35.25 (SD = 81.901) | Range : 0 - 266.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 69536.0 (SD = 14593.0) | Range : -1 - 84129
# 	----------------
# 	----------------
# 	AOI n°20 (participation of 12 observers)
# 		Mean fixation number : 1.333 (SD = 1.106) | Range : 0 - 4
# 		Mean viewing time (sec) : 0.934 (SD = 0.71) | Range : 0.0 - 2.618
# 		Mean fixation duration (ms) : 663.236 (SD = 410.067) | Range : 0 - 1222.0
# 		Mean gaze number : 1.25 (SD = 1.09) | Range : 0 - 4
# 		Mean time to first fixation (ms) : 68031.3 (SD = 19399.831) | Range : 25548 - 92331
# 	----------------
# 	----------------
# 	AOI n°21 (participation of 12 observers)
# 		Mean fixation number : 1.667 (SD = 1.247) | Range : 0 - 5
# 		Mean viewing time (sec) : 1.353 (SD = 1.113) | Range : 0.0 - 3.412
# 		Mean fixation duration (ms) : 826.511 (SD = 802.296) | Range : 0 - 2792.0
# 		Mean gaze number : 1.583 (SD = 1.256) | Range : 0 - 5
# 		Mean time to first fixation (ms) : 52243.0 (SD = 29705.951) | Range : 17348 - 108472
# 	----------------
# 	----------------
# 	AOI n°22 (participation of 12 observers)
# 		Mean fixation number : 0.333 (SD = 0.624) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.46 (SD = 0.901) | Range : 0.0 - 2.711
# 		Mean fixation duration (ms) : 371.667 (SD = 779.238) | Range : 0 - 2711.0
# 		Mean gaze number : 0.333 (SD = 0.624) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 31776.667 (SD = 2607.583) | Range : -1 - 33629
# 	----------------
# 	----------------
# 	AOI n°23 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°24 (participation of 12 observers)
# 		Mean fixation number : 0.5 (SD = 0.764) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.254 (SD = 0.451) | Range : 0.0 - 1.485
# 		Mean fixation duration (ms) : 169.792 (SD = 288.876) | Range : 0 - 827.0
# 		Mean gaze number : 0.5 (SD = 0.764) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 45769.75 (SD = 26228.506) | Range : -1 - 91187
# 	----------------
# 	----------------
# 	AOI n°25 (participation of 12 observers)
# 		Mean fixation number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.092 (SD = 0.305) | Range : 0.0 - 1.102
# 		Mean fixation duration (ms) : 91.833 (SD = 304.577) | Range : 0 - 1102.0
# 		Mean gaze number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 65989.0 (SD = 0.0) | Range : -1 - 65989
# 	----------------
# 	----------------
# 	AOI n°26 (participation of 12 observers)
# 		Mean fixation number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.085 (SD = 0.221) | Range : 0.0 - 0.787
# 		Mean fixation duration (ms) : 85.417 (SD = 221.446) | Range : 0 - 787.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 38582.5 (SD = 9529.5) | Range : -1 - 48112
# 	----------------
# 	----------------
# 	AOI n°27 (participation of 12 observers)
# 		Mean fixation number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.055 (SD = 0.183) | Range : 0.0 - 0.661
# 		Mean fixation duration (ms) : 55.083 (SD = 182.691) | Range : 0 - 661.0
# 		Mean gaze number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 40924.0 (SD = 0.0) | Range : -1 - 40924
# 	----------------
# 	----------------
# 	AOI n°28 (participation of 12 observers)
# 		Mean fixation number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.024 (SD = 0.079) | Range : 0.0 - 0.287
# 		Mean fixation duration (ms) : 23.917 (SD = 79.323) | Range : 0 - 287.0
# 		Mean gaze number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 63799.0 (SD = 0.0) | Range : -1 - 63799
# 	----------------
# 	----------------
# 	AOI n°29 (participation of 12 observers)
# 		Mean fixation number : 0.25 (SD = 0.433) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.099 (SD = 0.187) | Range : 0.0 - 0.561
# 		Mean fixation duration (ms) : 98.5 (SD = 186.695) | Range : 0 - 561.0
# 		Mean gaze number : 0.25 (SD = 0.433) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 46881.0 (SD = 17125.129) | Range : -1 - 65135
# 	----------------
# 	----------------
# 	AOI n°30 (participation of 12 observers)
# 		Mean fixation number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.069 (SD = 0.23) | Range : 0.0 - 0.831
# 		Mean fixation duration (ms) : 69.25 (SD = 229.676) | Range : 0 - 831.0
# 		Mean gaze number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 58253.0 (SD = 0.0) | Range : -1 - 58253
# 	----------------
# 	----------------
# 	AOI n°31 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°32 (participation of 12 observers)
# 		Mean fixation number : 1.0 (SD = 1.155) | Range : 0 - 4
# 		Mean viewing time (sec) : 0.909 (SD = 1.221) | Range : 0.0 - 4.301
# 		Mean fixation duration (ms) : 495.396 (SD = 492.168) | Range : 0 - 1356.0
# 		Mean gaze number : 0.833 (SD = 0.898) | Range : 0 - 3
# 		Mean time to first fixation (ms) : 23702.571 (SD = 8085.501) | Range : 12596 - 38736
# 	----------------
# 	----------------
# 	AOI n°33 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°34 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°35 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°36 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°37 (participation of 12 observers)
# 		Mean fixation number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.144 (SD = 0.398) | Range : 0.0 - 1.437
# 		Mean fixation duration (ms) : 143.583 (SD = 397.845) | Range : 0 - 1437.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 13203.0 (SD = 377.0) | Range : -1 - 13580
# 	----------------
# 	----------------
# 	AOI n°38 (participation of 12 observers)
# 		Mean fixation number : 0.333 (SD = 0.745) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.201 (SD = 0.449) | Range : 0.0 - 1.23
# 		Mean fixation duration (ms) : 100.458 (SD = 224.687) | Range : 0 - 615.0
# 		Mean gaze number : 0.333 (SD = 0.745) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 101781.5 (SD = 907.5) | Range : -1 - 102689
# 	----------------
# 	----------------
# 	AOI n°39 (participation of 12 observers)
# 		Mean fixation number : 0.417 (SD = 0.64) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.215 (SD = 0.342) | Range : 0.0 - 1.05
# 		Mean fixation duration (ms) : 171.417 (SD = 254.452) | Range : 0 - 729.0
# 		Mean gaze number : 0.5 (SD = 0.764) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 103520.5 (SD = 8267.923) | Range : -1 - 114444
# 	----------------
# 	----------------
# 	AOI n°40 (participation of 12 observers)
# 		Mean fixation number : 1.25 (SD = 1.785) | Range : 0 - 5
# 		Mean viewing time (sec) : 0.989 (SD = 1.56) | Range : 0.0 - 5.306
# 		Mean fixation duration (ms) : 373.475 (SD = 432.742) | Range : 0 - 1061.2
# 		Mean gaze number : 1.0 (SD = 1.472) | Range : 0 - 5
# 		Mean time to first fixation (ms) : 100861.5 (SD = 14945.048) | Range : -1 - 122518
# 	----------------
# 	----------------
# 	AOI n°41 (participation of 12 observers)
# 		Mean fixation number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.01 (SD = 0.035) | Range : 0.0 - 0.125
# 		Mean fixation duration (ms) : 10.417 (SD = 34.548) | Range : 0 - 125.0
# 		Mean gaze number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 91842.0 (SD = 0.0) | Range : -1 - 91842
# 	----------------
# 	----------------
# 	AOI n°42 (participation of 12 observers)
# 		Mean fixation number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.09 (SD = 0.218) | Range : 0.0 - 0.742
# 		Mean fixation duration (ms) : 90.083 (SD = 217.582) | Range : 0 - 742.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 45952.5 (SD = 16922.5) | Range : -1 - 62875
# 	----------------
# 	----------------
# 	AOI n°43 (participation of 12 observers)
# 		Mean fixation number : 0.667 (SD = 0.745) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.488 (SD = 0.725) | Range : 0.0 - 2.131
# 		Mean fixation duration (ms) : 361.708 (SD = 547.642) | Range : 0 - 1860.0
# 		Mean gaze number : 0.667 (SD = 0.745) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 65005.833 (SD = 15160.259) | Range : 43377 - 79743
# 	----------------
# 	----------------
# 	AOI n°44 (participation of 12 observers)
# 		Mean fixation number : 0.917 (SD = 1.115) | Range : 0 - 4
# 		Mean viewing time (sec) : 0.723 (SD = 1.25) | Range : 0.0 - 4.268
# 		Mean fixation duration (ms) : 361.833 (SD = 457.923) | Range : 0 - 1150.0
# 		Mean gaze number : 0.917 (SD = 1.115) | Range : 0 - 4
# 		Mean time to first fixation (ms) : 62546.0 (SD = 27255.411) | Range : 26468 - 101814
# 	----------------
# 	----------------
# 	AOI n°45 (participation of 12 observers)
# 		Mean fixation number : 1.0 (SD = 1.225) | Range : 0 - 3
# 		Mean viewing time (sec) : 0.533 (SD = 0.69) | Range : 0.0 - 2.025
# 		Mean fixation duration (ms) : 239.278 (SD = 331.931) | Range : 0 - 1012.5
# 		Mean gaze number : 1.0 (SD = 1.225) | Range : 0 - 3
# 		Mean time to first fixation (ms) : 57422.2 (SD = 22660.841) | Range : -1 - 89908
# 	----------------
# 	----------------
# 	AOI n°46 (participation of 12 observers)
# 		Mean fixation number : 0.667 (SD = 0.624) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.541 (SD = 0.679) | Range : 0.0 - 2.303
# 		Mean fixation duration (ms) : 444.625 (SD = 473.168) | Range : 0 - 1211.0
# 		Mean gaze number : 0.583 (SD = 0.493) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 72923.286 (SD = 23174.103) | Range : -1 - 97733
# 	----------------
# 	----------------
# 	AOI n°47 (participation of 12 observers)
# 		Mean fixation number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.013 (SD = 0.042) | Range : 0.0 - 0.153
# 		Mean fixation duration (ms) : 12.75 (SD = 42.287) | Range : 0 - 153.0
# 		Mean gaze number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 113283.0 (SD = 0.0) | Range : -1 - 113283
# 	----------------
# 	----------------
# 	AOI n°48 (participation of 12 observers)
# 		Mean fixation number : 0.417 (SD = 0.64) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.424 (SD = 0.617) | Range : 0.0 - 1.634
# 		Mean fixation duration (ms) : 370.5 (SD = 565.052) | Range : 0 - 1634.0
# 		Mean gaze number : 0.333 (SD = 0.471) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 52832.25 (SD = 5060.456) | Range : -1 - 60817
# 	----------------
# 	----------------
# 	AOI n°49 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°50 (participation of 12 observers)
# 		Mean fixation number : 0.25 (SD = 0.595) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.21 (SD = 0.526) | Range : 0.0 - 1.844
# 		Mean fixation duration (ms) : 133.0 (SD = 301.675) | Range : 0 - 922.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 27912.0 (SD = 27912.0) | Range : -1 - 55824
# 	----------------
# 	----------------
# 	AOI n°51 (participation of 12 observers)
# 		Mean fixation number : 0.75 (SD = 0.829) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.378 (SD = 0.482) | Range : 0.0 - 1.332
# 		Mean fixation duration (ms) : 232.792 (SD = 256.12) | Range : 0 - 666.0
# 		Mean gaze number : 0.75 (SD = 0.829) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 46841.167 (SD = 6732.53) | Range : 35863 - 56420
# 	----------------
# 	----------------
# 	AOI n°52 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°53 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°54 (participation of 12 observers)
# 		Mean fixation number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.093 (SD = 0.208) | Range : 0.0 - 0.581
# 		Mean fixation duration (ms) : 92.75 (SD = 207.636) | Range : 0 - 581.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 9911.0 (SD = 6615.0) | Range : 3296 - 16526
# 	----------------
# 	----------------
# 	AOI n°55 (participation of 12 observers)
# 		Mean fixation number : 0.75 (SD = 0.829) | Range : 0 - 3
# 		Mean viewing time (sec) : 0.919 (SD = 0.944) | Range : 0.0 - 2.498
# 		Mean fixation duration (ms) : 780.528 (SD = 817.465) | Range : 0 - 2498.0
# 		Mean gaze number : 0.75 (SD = 0.829) | Range : 0 - 3
# 		Mean time to first fixation (ms) : 7826.571 (SD = 4591.624) | Range : 1638 - 15973
# 	----------------
# 	----------------
# 	AOI n°56 (participation of 12 observers)
# 		Mean fixation number : 0.75 (SD = 0.924) | Range : 0 - 3
# 		Mean viewing time (sec) : 0.318 (SD = 0.652) | Range : 0.0 - 2.387
# 		Mean fixation duration (ms) : 156.597 (SD = 222.857) | Range : 0 - 795.667
# 		Mean gaze number : 0.75 (SD = 0.924) | Range : 0 - 3
# 		Mean time to first fixation (ms) : 29914.333 (SD = 47659.939) | Range : 0 - 131160
# 	----------------
# 	----------------
# 	AOI n°57 (participation of 12 observers)
# 		Mean fixation number : 1.75 (SD = 1.164) | Range : 0 - 4
# 		Mean viewing time (sec) : 1.56 (SD = 1.746) | Range : 0.0 - 6.661
# 		Mean fixation duration (ms) : 624.66 (SD = 520.512) | Range : 0 - 1665.25
# 		Mean gaze number : 1.667 (SD = 1.179) | Range : 0 - 4
# 		Mean time to first fixation (ms) : 51632.667 (SD = 11099.659) | Range : 36278 - 73001
# 	----------------
# 	----------------
# 	AOI n°58 (participation of 12 observers)
# 		Mean fixation number : 0.25 (SD = 0.433) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.136 (SD = 0.275) | Range : 0.0 - 0.92
# 		Mean fixation duration (ms) : 136.5 (SD = 275.069) | Range : 0 - 920.0
# 		Mean gaze number : 0.25 (SD = 0.433) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 67836.333 (SD = 18188.874) | Range : -1 - 80852
# 	----------------
# 	----------------
# 	AOI n°59 (participation of 12 observers)
# 		Mean fixation number : 0.917 (SD = 0.954) | Range : 0 - 3
# 		Mean viewing time (sec) : 0.746 (SD = 1.033) | Range : 0.0 - 3.139
# 		Mean fixation duration (ms) : 397.986 (SD = 431.219) | Range : 0 - 1151.5
# 		Mean gaze number : 0.833 (SD = 0.898) | Range : 0 - 3
# 		Mean time to first fixation (ms) : 50824.286 (SD = 21670.138) | Range : 16336 - 77343
# 	----------------
# 	----------------
# 	AOI n°60 (participation of 12 observers)
# 		Mean fixation number : 1.0 (SD = 0.913) | Range : 0 - 3
# 		Mean viewing time (sec) : 0.723 (SD = 0.895) | Range : 0.0 - 3.195
# 		Mean fixation duration (ms) : 442.0 (SD = 401.865) | Range : 0 - 1066.0
# 		Mean gaze number : 0.917 (SD = 0.759) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 57602.5 (SD = 10655.693) | Range : -1 - 80268
# 	----------------
# 	----------------
# 	AOI n°61 (participation of 12 observers)
# 		Mean fixation number : 1.333 (SD = 1.179) | Range : 0 - 3
# 		Mean viewing time (sec) : 0.629 (SD = 0.717) | Range : 0.0 - 2.268
# 		Mean fixation duration (ms) : 281.319 (SD = 265.204) | Range : 0 - 778.5
# 		Mean gaze number : 1.333 (SD = 1.179) | Range : 0 - 3
# 		Mean time to first fixation (ms) : 51335.125 (SD = 13729.101) | Range : 29928 - 74087
# 	----------------
# 	----------------
# 	AOI n°62 (participation of 12 observers)
# 		Mean fixation number : 0.667 (SD = 0.624) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.333 (SD = 0.375) | Range : 0.0 - 1.097
# 		Mean fixation duration (ms) : 287.708 (SD = 306.797) | Range : 0 - 863.0
# 		Mean gaze number : 0.667 (SD = 0.624) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 45292.429 (SD = 17385.603) | Range : 23342 - 74176
# 	----------------
# 	----------------
# 	AOI n°63 (participation of 12 observers)
# 		Mean fixation number : 7.417 (SD = 2.629) | Range : 3 - 12
# 		Mean viewing time (sec) : 5.522 (SD = 2.878) | Range : 1.702 - 13.015
# 		Mean fixation duration (ms) : 739.505 (SD = 228.838) | Range : 358.125 - 1084.583
# 		Mean gaze number : 5.75 (SD = 1.876) | Range : 3 - 9
# 		Mean time to first fixation (ms) : 33378.833 (SD = 17884.785) | Range : 5616 - 76625
# 	----------------
# 	----------------
# 	AOI n°64 (participation of 12 observers)
# 		Mean fixation number : 3.417 (SD = 2.431) | Range : 1 - 9
# 		Mean viewing time (sec) : 2.342 (SD = 1.582) | Range : 0.331 - 5.744
# 		Mean fixation duration (ms) : 675.424 (SD = 184.04) | Range : 331.0 - 954.0
# 		Mean gaze number : 3.083 (SD = 2.253) | Range : 1 - 8
# 		Mean time to first fixation (ms) : 59126.667 (SD = 21115.753) | Range : 29380 - 95149
# 	----------------
# 	----------------
# 	AOI n°65 (participation of 12 observers)
# 		Mean fixation number : 1.75 (SD = 1.164) | Range : 0 - 4
# 		Mean viewing time (sec) : 1.36 (SD = 0.895) | Range : 0.0 - 2.999
# 		Mean fixation duration (ms) : 782.938 (SD = 580.729) | Range : 0 - 2526.0
# 		Mean gaze number : 1.583 (SD = 0.862) | Range : 0 - 3
# 		Mean time to first fixation (ms) : 56338.364 (SD = 18322.09) | Range : 26440 - 83060
# 	----------------
# 	----------------
# 	AOI n°66 (participation of 12 observers)
# 		Mean fixation number : 0.333 (SD = 0.624) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.259 (SD = 0.543) | Range : 0.0 - 1.706
# 		Mean fixation duration (ms) : 210.083 (SD = 481.215) | Range : 0 - 1706.0
# 		Mean gaze number : 0.333 (SD = 0.624) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 83904.333 (SD = 24770.676) | Range : 60248 - 118108
# 	----------------
# 	----------------
# 	AOI n°67 (participation of 12 observers)
# 		Mean fixation number : 0.667 (SD = 0.85) | Range : 0 - 3
# 		Mean viewing time (sec) : 0.221 (SD = 0.364) | Range : 0.0 - 1.272
# 		Mean fixation duration (ms) : 150.417 (SD = 197.701) | Range : 0 - 650.0
# 		Mean gaze number : 0.583 (SD = 0.64) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 82541.333 (SD = 21799.876) | Range : 48468 - 113428
# 	----------------
# 	----------------
# 	AOI n°68 (participation of 12 observers)
# 		Mean fixation number : 2.583 (SD = 2.216) | Range : 0 - 8
# 		Mean viewing time (sec) : 1.489 (SD = 1.428) | Range : 0.0 - 5.179
# 		Mean fixation duration (ms) : 619.674 (SD = 562.572) | Range : 0 - 2025.0
# 		Mean gaze number : 1.75 (SD = 1.09) | Range : 0 - 4
# 		Mean time to first fixation (ms) : 94774.182 (SD = 20543.307) | Range : 53886 - 124099
# 	----------------
# 	----------------
# 	AOI n°69 (participation of 12 observers)
# 		Mean fixation number : 0.5 (SD = 0.645) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.372 (SD = 0.617) | Range : 0.0 - 2.15
# 		Mean fixation duration (ms) : 330.833 (SD = 590.013) | Range : 0 - 2150.0
# 		Mean gaze number : 0.5 (SD = 0.645) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 99650.0 (SD = 10497.813) | Range : -1 - 113698
# 	----------------
# 	----------------
# 	AOI n°70 (participation of 12 observers)
# 		Mean fixation number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.056 (SD = 0.133) | Range : 0.0 - 0.447
# 		Mean fixation duration (ms) : 55.667 (SD = 132.748) | Range : 0 - 447.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 98284.0 (SD = 8959.0) | Range : -1 - 107243
# 	----------------
# 	----------------
# 	AOI n°71 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°72 (participation of 12 observers)
# 		Mean fixation number : 0.25 (SD = 0.433) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.246 (SD = 0.539) | Range : 0.0 - 1.912
# 		Mean fixation duration (ms) : 246.417 (SD = 539.036) | Range : 0 - 1912.0
# 		Mean gaze number : 0.25 (SD = 0.433) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 61368.0 (SD = 4147.219) | Range : -1 - 65380
# 	----------------
# 	----------------
# 	AOI n°73 (participation of 12 observers)
# 		Mean fixation number : 0.833 (SD = 0.687) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.422 (SD = 0.52) | Range : 0.0 - 1.36
# 		Mean fixation duration (ms) : 318.292 (SD = 389.363) | Range : 0 - 1360.0
# 		Mean gaze number : 0.75 (SD = 0.595) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 36903.375 (SD = 23415.054) | Range : -1 - 76489
# 	----------------
# 	----------------
# 	AOI n°74 (participation of 12 observers)
# 		Mean fixation number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.117 (SD = 0.264) | Range : 0.0 - 0.791
# 		Mean fixation duration (ms) : 116.667 (SD = 263.507) | Range : 0 - 791.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 52524.0 (SD = 20841.0) | Range : -1 - 73365
# 	----------------
# 	----------------
# 	AOI n°75 (participation of 12 observers)
# 		Mean fixation number : 4.333 (SD = 2.095) | Range : 1 - 8
# 		Mean viewing time (sec) : 3.075 (SD = 1.951) | Range : 0.432 - 6.798
# 		Mean fixation duration (ms) : 720.385 (SD = 348.822) | Range : 216.0 - 1381.0
# 		Mean gaze number : 3.25 (SD = 1.831) | Range : 1 - 6
# 		Mean time to first fixation (ms) : 8757.75 (SD = 9630.11) | Range : 0 - 22944
# 	----------------
# 	----------------
# 	AOI n°76 (participation of 12 observers)
# 		Mean fixation number : 0.167 (SD = 0.553) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.134 (SD = 0.446) | Range : 0.0 - 1.614
# 		Mean fixation duration (ms) : 67.25 (SD = 223.043) | Range : 0 - 807.0
# 		Mean gaze number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 120896.0 (SD = 0.0) | Range : -1 - 120896
# 	----------------
# 	----------------
# 	AOI n°77 (participation of 12 observers)
# 		Mean fixation number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.066 (SD = 0.219) | Range : 0.0 - 0.794
# 		Mean fixation duration (ms) : 66.167 (SD = 219.45) | Range : 0 - 794.0
# 		Mean gaze number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 16550.0 (SD = 0.0) | Range : 16550 - 16550
# 	----------------
# 	----------------
# 	AOI n°78 (participation of 12 observers)
# 		Mean fixation number : 0.583 (SD = 0.493) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.481 (SD = 0.678) | Range : 0.0 - 1.961
# 		Mean fixation duration (ms) : 480.833 (SD = 678.108) | Range : 0 - 1961.0
# 		Mean gaze number : 0.583 (SD = 0.493) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 47508.714 (SD = 22076.67) | Range : 19446 - 88402
# 	----------------
# 	----------------
# 	AOI n°79 (participation of 12 observers)
# 		Mean fixation number : 0.583 (SD = 1.187) | Range : 0 - 4
# 		Mean viewing time (sec) : 0.352 (SD = 0.677) | Range : 0.0 - 2.207
# 		Mean fixation duration (ms) : 184.333 (SD = 359.526) | Range : 0 - 1103.5
# 		Mean gaze number : 0.5 (SD = 0.957) | Range : 0 - 3
# 		Mean time to first fixation (ms) : 54340.0 (SD = 12218.048) | Range : -1 - 71610
# 	----------------
# 	----------------
# 	AOI n°80 (participation of 12 observers)
# 		Mean fixation number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.016 (SD = 0.052) | Range : 0.0 - 0.187
# 		Mean fixation duration (ms) : 15.583 (SD = 51.684) | Range : 0 - 187.0
# 		Mean gaze number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 20062.0 (SD = 0.0) | Range : -1 - 20062
# 	----------------
# 	----------------
# 	AOI n°81 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°82 (participation of 12 observers)
# 		Mean fixation number : 0.667 (SD = 0.745) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.329 (SD = 0.428) | Range : 0.0 - 1.198
# 		Mean fixation duration (ms) : 234.208 (SD = 273.099) | Range : 0 - 642.0
# 		Mean gaze number : 0.667 (SD = 0.745) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 14048.667 (SD = 6993.974) | Range : -1 - 23054
# 	----------------
# 	----------------
# 	AOI n°83 (participation of 12 observers)
# 		Mean fixation number : 1.667 (SD = 1.027) | Range : 0 - 3
# 		Mean viewing time (sec) : 1.182 (SD = 0.702) | Range : 0.0 - 2.048
# 		Mean fixation duration (ms) : 635.5 (SD = 407.575) | Range : 0 - 1577.0
# 		Mean gaze number : 1.5 (SD = 0.957) | Range : 0 - 3
# 		Mean time to first fixation (ms) : 11388.8 (SD = 9156.194) | Range : 440 - 27967
# 	----------------
# 	----------------
# 	AOI n°84 (participation of 12 observers)
# 		Mean fixation number : 1.667 (SD = 1.312) | Range : 0 - 5
# 		Mean viewing time (sec) : 1.385 (SD = 0.992) | Range : 0.0 - 3.094
# 		Mean fixation duration (ms) : 744.911 (SD = 478.167) | Range : 0 - 1650.0
# 		Mean gaze number : 1.583 (SD = 1.115) | Range : 0 - 4
# 		Mean time to first fixation (ms) : 52536.1 (SD = 28580.803) | Range : 20286 - 104298
# 	----------------
# 	----------------
# 	AOI n°85 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°86 (participation of 12 observers)
# 		Mean fixation number : 0.25 (SD = 0.595) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.027 (SD = 0.066) | Range : 0.0 - 0.226
# 		Mean fixation duration (ms) : 17.917 (SD = 40.126) | Range : 0 - 113.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 107192.0 (SD = 17444.0) | Range : -1 - 124636
# 	----------------
# 	----------------
# 	AOI n°87 (participation of 12 observers)
# 		Mean fixation number : 0.25 (SD = 0.433) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.241 (SD = 0.453) | Range : 0.0 - 1.412
# 		Mean fixation duration (ms) : 241.083 (SD = 452.798) | Range : 0 - 1412.0
# 		Mean gaze number : 0.25 (SD = 0.433) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 44633.333 (SD = 17273.525) | Range : 20903 - 61520
# 	----------------
# 	----------------
# 	AOI n°88 (participation of 12 observers)
# 		Mean fixation number : 0.25 (SD = 0.595) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.1 (SD = 0.246) | Range : 0.0 - 0.847
# 		Mean fixation duration (ms) : 65.208 (SD = 146.403) | Range : 0 - 423.5
# 		Mean gaze number : 0.25 (SD = 0.595) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 110695.0 (SD = 9543.0) | Range : -1 - 120238
# 	----------------
# 	----------------
# 	AOI n°89 (participation of 12 observers)
# 		Mean fixation number : 0.25 (SD = 0.433) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.216 (SD = 0.561) | Range : 0.0 - 2.042
# 		Mean fixation duration (ms) : 216.25 (SD = 560.699) | Range : 0 - 2042.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 19617.667 (SD = 16647.195) | Range : -1 - 41278
# 	----------------
# 	----------------
# 	AOI n°90 (participation of 12 observers)
# 		Mean fixation number : 0.917 (SD = 0.954) | Range : 0 - 3
# 		Mean viewing time (sec) : 0.662 (SD = 1.062) | Range : 0.0 - 3.905
# 		Mean fixation duration (ms) : 351.472 (SD = 389.522) | Range : 0 - 1301.667
# 		Mean gaze number : 0.917 (SD = 0.954) | Range : 0 - 3
# 		Mean time to first fixation (ms) : 46286.286 (SD = 31948.767) | Range : -1 - 86910
# 	----------------
# 	----------------
# 	AOI n°91 (participation of 12 observers)
# 		Mean fixation number : 2.0 (SD = 1.683) | Range : 0 - 5
# 		Mean viewing time (sec) : 1.565 (SD = 1.28) | Range : 0.0 - 3.483
# 		Mean fixation duration (ms) : 721.421 (SD = 634.062) | Range : 0 - 2489.0
# 		Mean gaze number : 1.75 (SD = 1.422) | Range : 0 - 5
# 		Mean time to first fixation (ms) : 98438.0 (SD = 13792.227) | Range : 65424 - 116534
# 	----------------
# 	----------------
# 	AOI n°92 (participation of 12 observers)
# 		Mean fixation number : 2.0 (SD = 1.528) | Range : 0 - 5
# 		Mean viewing time (sec) : 1.419 (SD = 1.501) | Range : 0.0 - 5.092
# 		Mean fixation duration (ms) : 562.764 (SD = 524.413) | Range : 0 - 1697.333
# 		Mean gaze number : 1.667 (SD = 1.179) | Range : 0 - 4
# 		Mean time to first fixation (ms) : 4089.9 (SD = 3311.931) | Range : 682 - 8001
# 	----------------
# 	----------------
# 	AOI n°93 (participation of 12 observers)
# 		Mean fixation number : 0.25 (SD = 0.433) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.162 (SD = 0.4) | Range : 0.0 - 1.449
# 		Mean fixation duration (ms) : 162.417 (SD = 400.122) | Range : 0 - 1449.0
# 		Mean gaze number : 0.25 (SD = 0.433) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 19318.667 (SD = 10271.23) | Range : -1 - 33176
# 	----------------
# 	----------------
# 	AOI n°94 (participation of 12 observers)
# 		Mean fixation number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.036 (SD = 0.119) | Range : 0.0 - 0.432
# 		Mean fixation duration (ms) : 36.0 (SD = 119.398) | Range : 0 - 432.0
# 		Mean gaze number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 59704.0 (SD = 0.0) | Range : -1 - 59704
# 	----------------
# 	----------------
# 	AOI n°95 (participation of 12 observers)
# 		Mean fixation number : 0.333 (SD = 0.624) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.33 (SD = 0.739) | Range : 0.0 - 2.646
# 		Mean fixation duration (ms) : 219.583 (SD = 411.562) | Range : 0 - 1323.0
# 		Mean gaze number : 0.333 (SD = 0.624) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 42756.667 (SD = 11921.264) | Range : -1 - 56487
# 	----------------
# 	----------------
# 	AOI n°96 (participation of 12 observers)
# 		Mean fixation number : 1.75 (SD = 1.534) | Range : 0 - 5
# 		Mean viewing time (sec) : 1.036 (SD = 1.483) | Range : 0.0 - 5.494
# 		Mean fixation duration (ms) : 359.581 (SD = 301.042) | Range : 0 - 1098.8
# 		Mean gaze number : 1.75 (SD = 1.534) | Range : 0 - 5
# 		Mean time to first fixation (ms) : 21515.556 (SD = 10218.046) | Range : 492 - 37501
# 	----------------
# 	----------------
# 	AOI n°97 (participation of 12 observers)
# 		Mean fixation number : 0.583 (SD = 0.862) | Range : 0 - 3
# 		Mean viewing time (sec) : 0.4 (SD = 0.653) | Range : 0.0 - 2.179
# 		Mean fixation duration (ms) : 328.222 (SD = 596.244) | Range : 0 - 2179.0
# 		Mean gaze number : 0.5 (SD = 0.866) | Range : 0 - 3
# 		Mean time to first fixation (ms) : 26825.8 (SD = 15356.465) | Range : -1 - 45647
# 	----------------
# 	----------------
# 	AOI n°98 (participation of 12 observers)
# 		Mean fixation number : 4.583 (SD = 2.06) | Range : 1 - 8
# 		Mean viewing time (sec) : 4.337 (SD = 2.741) | Range : 0.363 - 8.553
# 		Mean fixation duration (ms) : 980.229 (SD = 637.758) | Range : 181.5 - 2584.667
# 		Mean gaze number : 2.917 (SD = 1.187) | Range : 1 - 5
# 		Mean time to first fixation (ms) : 5626.333 (SD = 5798.405) | Range : 266 - 21536
# 	----------------
# 	----------------
# 	AOI n°99 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°100 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°101 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°102 (participation of 12 observers)
# 		Mean fixation number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.023 (SD = 0.08) | Range : -0.008 - 0.287
# 		Mean fixation duration (ms) : 23.25 (SD = 79.554) | Range : -8.0 - 287.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 35199.5 (SD = 7865.5) | Range : -1 - 43065
# 	----------------
# 	----------------
# 	AOI n°103 (participation of 12 observers)
# 		Mean fixation number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean viewing time (sec) : 0.0 (SD = 0.0) | Range : 0.0 - 0.0
# 		Mean fixation duration (ms) : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean gaze number : 0.0 (SD = 0.0) | Range : 0 - 0
# 		Mean time to first fixation (ms) : nan (SD = nan) | Range : -1 - -1
# 	----------------
# 	----------------
# 	AOI n°104 (participation of 12 observers)
# 		Mean fixation number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.015 (SD = 0.049) | Range : 0.0 - 0.178
# 		Mean fixation duration (ms) : 14.833 (SD = 49.197) | Range : 0 - 178.0
# 		Mean gaze number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 12128.0 (SD = 0.0) | Range : -1 - 12128
# 	----------------
# Image n°144 (Vaillant_0622_1957_04_14-32)
# 	----------------
# 	AOI n°0 (participation of 12 observers)
# 		Mean fixation number : 3.5 (SD = 1.607) | Range : 1 - 6
# 		Mean viewing time (sec) : 2.902 (SD = 1.075) | Range : 1.655 - 5.257
# 		Mean fixation duration (ms) : 967.076 (SD = 427.926) | Range : 402.6 - 2086.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 9927.333 (SD = 7774.452) | Range : 129 - 21246
# 	----------------
# 	----------------
# 	AOI n°1 (participation of 12 observers)
# 		Mean fixation number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.301 (SD = 0.937) | Range : 0.0 - 3.401
# 		Mean fixation duration (ms) : 300.583 (SD = 936.529) | Range : 0 - 3401.0
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 19969.0 (SD = 1652.0) | Range : -1 - 21621
# 	----------------
# Image n°146 (Vaillant_0622_1957_04_14-30)
# 	----------------
# 	AOI n°0 (participation of 12 observers)
# 		Mean fixation number : 4.917 (SD = 3.328) | Range : 0 - 12
# 		Mean viewing time (sec) : 3.307 (SD = 2.147) | Range : 0.0 - 7.416
# 		Mean fixation duration (ms) : 594.587 (SD = 335.883) | Range : 0 - 1059.429
# 		Mean gaze number : 0.333 (SD = 0.624) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 14364.8 (SD = 10327.295) | Range : 0 - 28584
# 	----------------
# 	----------------
# 	AOI n°1 (participation of 12 observers)
# 		Mean fixation number : 0.333 (SD = 0.624) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.082 (SD = 0.198) | Range : 0.0 - 0.719
# 		Mean fixation duration (ms) : 51.792 (SD = 105.169) | Range : 0 - 359.5
# 		Mean gaze number : 0.167 (SD = 0.373) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 22526.0 (SD = 8268.079) | Range : -1 - 34184
# 	----------------
# Image n°234 (Vaillant_0499_1954_12_05-01)
# 	----------------
# 	AOI n°0 (participation of 12 observers)
# 		Mean fixation number : 0.333 (SD = 0.471) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.107 (SD = 0.177) | Range : 0.0 - 0.504
# 		Mean fixation duration (ms) : 106.917 (SD = 177.255) | Range : 0 - 504.0
# 		Mean gaze number : 0.333 (SD = 0.471) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 9374.0 (SD = 10286.667) | Range : -1 - 26005
# 	----------------
# 	----------------
# 	AOI n°1 (participation of 12 observers)
# 		Mean fixation number : 0.167 (SD = 0.553) | Range : 0 - 2
# 		Mean viewing time (sec) : 0.037 (SD = 0.122) | Range : 0.0 - 0.443
# 		Mean fixation duration (ms) : 18.458 (SD = 61.219) | Range : 0 - 221.5
# 		Mean gaze number : 0.167 (SD = 0.553) | Range : 0 - 2
# 		Mean time to first fixation (ms) : 16335.0 (SD = 0.0) | Range : -1 - 16335
# 	----------------
# 	----------------
# 	AOI n°2 (participation of 12 observers)
# 		Mean fixation number : 0.25 (SD = 0.433) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.152 (SD = 0.268) | Range : 0.0 - 0.718
# 		Mean fixation duration (ms) : 151.583 (SD = 268.29) | Range : 0 - 718.0
# 		Mean gaze number : 0.25 (SD = 0.433) | Range : 0 - 1
# 		Mean time to first fixation (ms) : 18663.0 (SD = 10654.94) | Range : -1 - 32914
# 	----------------
# 	----------------
# 	AOI n°3 (participation of 12 observers)
# 		Mean fixation number : 0.083 (SD = 0.276) | Range : 0 - 1
# 		Mean viewing time (sec) : 0.027 (SD = 0.089) | Range : 0.0 - 0.322
# 		Mean fixation duration (ms) : 26.833 (SD = 88.996) | Range : 0 - 322.0
# ...
# this is val :  35379.0
# this is val :  0.0
# this is val :  35379
# this is val :  -1
# this is val :  nan
# this is val :  nan
# this is val :  -1
# this is val :  -1
# this is curItem : : {'mean': 0.0, 'stdDev': 0.0, 'boundUp': 0, 'boundDown': 0}
# this is val :  23233.5
# this is val :  1018.5
# this is val :  24252
# this is val :  -1
# this is val :  nan
# this is val :  nan
# this is val :  -1
# this is val :  -1
# this is curItem : : {'mean': 0.0, 'stdDev': 0.0, 'boundUp': 0, 'boundDown': 0}
# this is val :  nan
# this is val :  nan
# this is val :  -1
# this is val :  -1
# this is curItem : : {'mean': 0.0, 'stdDev': 0.0, 'boundUp': 0, 'boundDown': 0}
# this is val :  nan
# this is val :  nan
# this is val :  -1
# this is val :  -1
# this is curItem : : {'mean': 0.0, 'stdDev': 0.0, 'boundUp': 0, 'boundDown': 0}
# this is val :  0.27
# this is val :  0.481
# this is val :  1.569
# this is val :  0.0
# this is val :  0.427
# this is val :  0.656
# this is val :  2.074
# this is val :  0.0
# this is val :  0.121
# this is val :  0.21
# this is val :  0.529
# this is val :  0.0
# this is val :  0.401
# this is val :  0.74
# this is val :  2.708
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.084
# this is val :  0.22
# this is val :  0.783
# this is val :  0.0
# this is val :  0.248
# this is val :  0.446
# this is val :  1.485
# this is val :  0.0
# this is val :  1.06
# this is val :  0.698
# this is val :  2.106
# this is val :  0.0
# this is val :  0.045
# this is val :  0.15
# this is val :  0.541
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.021
# this is val :  0.07
# this is val :  0.254
# this is val :  0.0
# this is val :  0.284
# this is val :  0.346
# this is val :  0.851
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.265
# this is val :  0.397
# this is val :  1.033
# this is val :  0.0
# this is val :  0.495
# this is val :  0.708
# this is val :  2.082
# this is val :  0.0
# this is val :  0.204
# this is val :  0.314
# this is val :  0.896
# this is val :  0.0
# this is val :  0.358
# this is val :  0.704
# this is val :  2.4
# this is val :  0.0
# this is val :  2.807
# this is val :  1.697
# this is val :  5.793
# this is val :  0.198
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.789
# this is val :  1.079
# this is val :  3.026
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.502
# this is val :  0.906
# this is val :  3.381
# this is val :  0.0
# this is val :  0.97
# this is val :  0.788
# this is val :  2.227
# this is val :  0.0
# this is val :  0.03
# this is val :  0.099
# this is val :  0.359
# this is val :  0.0
# this is val :  0.164
# this is val :  0.349
# this is val :  1.194
# this is val :  0.0
# this is val :  0.077
# this is val :  0.154
# this is val :  0.528
# this is val :  0.0
# this is val :  0.082
# this is val :  0.217
# this is val :  0.778
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  1.374
# this is val :  1.041
# this is val :  3.243
# this is val :  0.0
# this is val :  0.143
# this is val :  0.473
# this is val :  1.711
# this is val :  0.0
# this is val :  0.029
# this is val :  0.095
# this is val :  0.343
# this is val :  0.0
# this is val :  0.116
# this is val :  0.265
# this is val :  0.823
# this is val :  0.0
# this is val :  0.22
# this is val :  0.514
# this is val :  1.69
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.684
# this is val :  0.785
# this is val :  2.171
# this is val :  0.0
# this is val :  0.418
# this is val :  0.905
# this is val :  2.901
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.184
# this is val :  0.245
# this is val :  0.613
# this is val :  0.0
# this is val :  0.429
# this is val :  0.622
# this is val :  1.788
# this is val :  0.0
# this is val :  0.048
# this is val :  0.158
# this is val :  0.573
# this is val :  0.0
# this is val :  0.052
# this is val :  0.173
# this is val :  0.626
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.036
# this is val :  0.118
# this is val :  0.428
# this is val :  0.0
# this is val :  0.111
# this is val :  0.247
# this is val :  0.681
# this is val :  0.0
# this is val :  0.268
# this is val :  0.413
# this is val :  1.324
# this is val :  0.0
# this is val :  0.071
# this is val :  0.235
# this is val :  0.852
# this is val :  0.0
# this is val :  0.368
# this is val :  0.592
# this is val :  1.893
# this is val :  0.0
# this is val :  0.049
# this is val :  0.162
# this is val :  0.585
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.11
# this is val :  0.227
# this is val :  0.763
# this is val :  0.0
# this is val :  0.584
# this is val :  0.551
# this is val :  1.945
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.028
# this is val :  0.067
# this is val :  0.226
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.104
# this is val :  0.346
# this is val :  1.251
# this is val :  0.0
# this is val :  0.054
# this is val :  0.181
# this is val :  0.654
# this is val :  0.0
# this is val :  0.198
# this is val :  0.338
# this is val :  1.154
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.112
# this is val :  0.25
# this is val :  0.694
# this is val :  0.0
# this is val :  0.02
# this is val :  0.067
# this is val :  0.242
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.359
# this is val :  0.447
# this is val :  1.053
# this is val :  0.0
# this is val :  0.012
# this is val :  0.039
# this is val :  0.141
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.453
# this is val :  0.518
# this is val :  1.477
# this is val :  0.0
# this is val :  0.269
# this is val :  0.224
# this is val :  0.843
# this is val :  0.0
# this is val :  1.033
# this is val :  1.006
# this is val :  2.9
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.175
# this is val :  0.246
# this is val :  0.801
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.039
# this is val :  0.088
# this is val :  0.255
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.028
# this is val :  0.094
# this is val :  0.339
# this is val :  0.0
# this is val :  0.518
# this is val :  0.721
# this is val :  2.369
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.619
# this is val :  0.569
# this is val :  1.832
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.396
# this is val :  0.482
# this is val :  1.715
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.023
# this is val :  0.075
# this is val :  0.27
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.19
# this is val :  0.371
# this is val :  1.316
# this is val :  0.0
# this is val :  0.018
# this is val :  0.041
# this is val :  0.117
# this is val :  0.0
# this is val :  0.117
# this is val :  0.268
# this is val :  0.851
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.079
# this is val :  0.189
# this is val :  0.642
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.17
# this is val :  0.298
# this is val :  0.819
# this is val :  0.0
# this is val :  0.185
# this is val :  0.525
# this is val :  1.916
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.031
# this is val :  0.103
# this is val :  0.372
# this is val :  0.0
# this is val :  0.022
# this is val :  0.074
# this is val :  0.266
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.193
# this is val :  0.422
# this is val :  1.384
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.255
# this is val :  0.404
# this is val :  1.287
# this is val :  0.0
# this is val :  0.01
# this is val :  0.035
# this is val :  0.125
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.182
# this is val :  0.259
# this is val :  0.932
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.026
# this is val :  0.087
# this is val :  0.315
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.141
# this is val :  0.277
# this is val :  0.791
# this is val :  0.0
# this is val :  0.181
# this is val :  0.283
# this is val :  0.73
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.143
# this is val :  0.299
# this is val :  1.045
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.286
# this is val :  0.641
# this is val :  1.844
# this is val :  0.0
# this is val :  0.028
# this is val :  0.095
# this is val :  0.342
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.015
# this is val :  0.051
# this is val :  0.185
# this is val :  0.0
# this is val :  0.19
# this is val :  0.402
# this is val :  1.384
# this is val :  0.0
# this is val :  0.049
# this is val :  0.163
# this is val :  0.589
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.058
# this is val :  0.193
# this is val :  0.698
# this is val :  0.0
# this is val :  1.471
# this is val :  1.379
# this is val :  4.087
# this is val :  0.0
# this is val :  0.02
# this is val :  0.066
# this is val :  0.238
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.146
# this is val :  0.485
# this is val :  1.755
# this is val :  0.0
# this is val :  0.209
# this is val :  0.631
# this is val :  2.292
# this is val :  0.0
# this is val :  0.098
# this is val :  0.249
# this is val :  0.88
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.093
# this is val :  0.309
# this is val :  1.117
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.221
# this is val :  0.732
# this is val :  2.647
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.116
# this is val :  0.386
# this is val :  1.395
# this is val :  0.0
# this is val :  0.078
# this is val :  0.258
# this is val :  0.932
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.23
# this is val :  0.762
# this is val :  2.756
# this is val :  0.0
# this is val :  0.121
# this is val :  0.23
# this is val :  0.746
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.057
# this is val :  0.19
# this is val :  0.686
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.141
# this is val :  0.368
# this is val :  1.312
# this is val :  0.0
# this is val :  0.084
# this is val :  0.166
# this is val :  0.544
# this is val :  0.0
# this is val :  0.826
# this is val :  1.266
# this is val :  3.514
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.031
# this is val :  0.101
# this is val :  0.367
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.037
# this is val :  0.093
# this is val :  0.327
# this is val :  0.0
# this is val :  0.172
# this is val :  0.475
# this is val :  1.715
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.013
# this is val :  0.042
# this is val :  0.153
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.45
# this is val :  0.961
# this is val :  3.425
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.01
# this is val :  0.032
# this is val :  0.117
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.135
# this is val :  0.309
# this is val :  0.977
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# this is val :  0.0
# 2

# %%
"""
Visualisations
"""
if conf.ARE_AOIS_LOAD and conf.ARE_FIXATIONS_LOAD:
    vs.drawAOIOverImages(conf)
    
if conf.ARE_IMAGES_LOAD:
        #Heatmaps and focusmaps
        vs.generateAllHeatmapsAndFocusmap(conf, saveFiles=True)
        
        #gc.collect()

        #Gazeplots
        vs.createAllGazeplots(conf)
        
        gc.collect()

        #Scanpaths
        vs.createAllScanpaths(conf)
        
        #gc.collect()
print("3")

# %%
"""
Compute all binary map 
"""
#Compute all binary maps
binMapDictionnary = vs.computeAllBinaryMap(conf)

#Compute sum of binary maps by images
sumBinMaps = me.computeSumBinMapsByImages(binMapDictionnary, conf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/z3/q3dm3kvj43q24611cgswtyph0000gp/T/ipykernel_31678/4008254335.py in <module>
#       3 """
#       4 #Compute all binary maps
# ----> 5 binMapDictionnary = vs.computeAllBinaryMap(conf)
#       6
#       7 #Compute sum of binary maps by images
#
# NameError: name 'vs' is not defined

# %%
"""
Inter-observer consistency
"""
#IOC scores
iocScores, iocScoresMean = me.computeIOCScore(binMapDictionnary, sumBinMaps, conf, plotCurve=False, saveSaliencyMap=True, saveCombinedMaps=True)

#Print IOC scores
me.printIOCScores(iocScores, iocScoresMean, conf)
print("4")
# Out:
# 4

# %%
"""
Predictions using DeepGaze and ICF
"""
predictions = mo.predictAllSaliencyMaps(conf, saveFiles = True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/z3/q3dm3kvj43q24611cgswtyph0000gp/T/ipykernel_31084/3651388748.py in <module>
#       2 Predictions using DeepGaze and ICF
#       3 """
# ----> 4 predictions = mo.predictAllSaliencyMaps(conf, saveFiles = True)
#
# ~/Documents/python_scripts/Models.py in predictAllSaliencyMaps(conf, saveFiles)
#      22         tf.reset_default_graph()
#      23         check_point_path = conf.DEEP_GAZE_RESOURCES_FOLDER + check_point
# ---> 24         new_saver = tf.train.import_meta_graph( '{}.meta'.format(check_point_path))
#      25
#      26         curSaliencyMaps = {}
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/training/saver.py in import_meta_graph(meta_graph_or_file, clear_devices, import_scope, **kwargs)
#    1578   @end_compatibility
#    1579   """  # pylint: disable=g-doc-exception
# -> 1580   return _import_meta_graph_with_return_elements(meta_graph_or_file,
#    1581                                                  clear_devices, import_scope,
#    1582                                                  **kwargs)[0]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/training/saver.py in _import_meta_graph_with_return_elements(meta_graph_or_file, clear_devices, import_scope, return_elements, **kwargs)
#    1594                        "execution is enabled.")
#    1595   if not isinstance(meta_graph_or_file, meta_graph_pb2.MetaGraphDef):
# -> 1596     meta_graph_def = meta_graph.read_meta_graph_file(meta_graph_or_file)
#    1597   else:
#    1598     meta_graph_def = meta_graph_or_file
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/meta_graph.py in read_meta_graph_file(filename)
#     631   meta_graph_def = meta_graph_pb2.MetaGraphDef()
#     632   if not file_io.file_exists(filename):
# --> 633     raise IOError(f"File does not exist. Received: {filename}.")
#     634   # First try to read it as a binary file.
#     635   with file_io.FileIO(filename, "rb") as f:
#
# OSError: File does not exist. Received: resources/deepGazeFiles/DeepGazeII.ckpt.meta.

# %% [markdown]
# """
# Compute and print AUC Scores for the models
# """
# #Get the AUC scores for DeepGaze and ICF Model
# modelScores, meanScoresModel = mo.computeModelScores(predictions, sumBinMaps,conf)
#
# #Print the scores for the models
# mo.printModelScores(modelScores, meanScoresModel, conf)

# %%
from matplotlib import pyplot
for c in sumBinMaps:
    fig1, ax1, fig2, ax2, imageName = vs.getBasicFigures(c, conf, drawImage=False)
    ax1.imshow(vs.blur(sumBinMaps[c]), cmap='gray',alpha=1.0)
    ax1.invert_yaxis()
    fig1.show()
    
    path = conf.OUTPUTS +"/saliencyMapNObservers/"+imageName+".jpg"
    fig1.savefig(path)

    #Close figures
    pyplot.close(fig1)
    pyplot.close(fig2)
